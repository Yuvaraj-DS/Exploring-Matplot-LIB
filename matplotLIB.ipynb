# %% [markdown]
# ## Exploring MatplotLIB

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Graph

# %%
plt.plot([1,2,3],[2,4,6])

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y)

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y)
plt.show()

# %%
# adding title, x label and y label
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y)
plt.title('My First Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
# adding font and font size
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y)
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
# Out:
# findfont: Font family ['Cosmic Sans Ms'] not found. Falling back to DejaVu Sans.

# %%
# adding ticks
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y)
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.show()

# %%
# adding legend
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y, label = '2x')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# adding legend color
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y, label = '2x', color = '#ababab')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# adding legend color
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y, label = '2x', color = 'red')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
 # adding line width
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y, label = '2x', color = 'red', linewidth = 2)
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# adding marker, marker size and marker color
x = [1,2,3]
y = [2,4,6]
plt.plot(x, y, label = '2x', color = 'red', marker = '.', markersize = 10, markeredgecolor = 'blue')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# short hand notation
x = [1,2,3]
y = [2,4,6]
# plt.plot(x, y, label = '2x', color = 'red', marker = '.', markersize = 10, markeredgecolor = 'blue')
# format = [color][marker][line]
plt.plot(x, y, 'r.-',label = '2x')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# short hand notation
x = [1,2,3]
y = [2,4,6]
# plt.plot(x, y, label = '2x', color = 'red', marker = '.', markersize = 10, markeredgecolor = 'blue')
# format = [color][marker][line]
plt.plot(x, y, 'r.--',label = '2x')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# short hand notation
x = [1,2,3]
y = [2,4,6]
# plt.plot(x, y, label = '2x', color = 'red', marker = '.', markersize = 10, markeredgecolor = 'blue')
# format = [color][marker][line]
plt.plot(x, y, 'b^--',label = '2x')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %% [raw]
# Markers
#
# '.'	point marker
# ','	pixel marker
# 'o'	circle marker
# 'v'	triangle_down marker
# '^'	triangle_up marker
# '<'	triangle_left marker
# '>'	triangle_right marker
# '1'	tri_down marker
# '2'	tri_up marker
# '3'	tri_left marker
# '4'	tri_right marker
# 's'	square marker
# 'p'	pentagon marker
# '*'	star marker
# 'h'	hexagon1 marker
# 'H'	hexagon2 marker
# '+'	plus marker
# 'x'	x marker
# 'D'	diamond marker
# 'd'	thin_diamond marker
# '|'	vline marker
# '_'	hline marker
#
# Line Styles
#
# '-'	solid line style
# '--'	dashed line style
# '-.'	dash-dot line style
# ':'	dotted line style
#
# Colors
#
# 'b'	blue
# 'g'	green
# 'r'	red
# 'c'	cyan
# 'm'	magenta
# 'y'	yellow
# 'k'	black
# 'w'	white

# %%
x2 = np.arange(0, 4, 0.5)
x2
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5])

# %%
# multiple lines
plt.plot(x, y, 'b^--',label = '2x')
x2 = np.arange(0, 4, 0.5)
plt.plot(x2, x2 ** 2, 'r', label = 'x^2')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# plot only 1st 4 values
plt.plot(x, y, 'b^--',label = '2x')
x2 = np.arange(0, 4, 0.5)
plt.plot(x2[:4], x2[:4] ** 2, 'r', label = 'x^2')
plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# plot only 1st 4 values
plt.plot(x, y, 'b^--',label = '2x')
x2 = np.arange(0, 4, 0.5)

plt.plot(x2[:6], x2[:6] ** 2, 'r', label = 'x^2')
plt.plot(x2[5:], x2[5:] ** 2, 'g--')

plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# resize graph, dpi =. pixels per inch 

plt.figure(figsize=(5,3), dpi = 300)
plt.plot(x, y, 'b^--',label = '2x')
x2 = np.arange(0, 4, 0.5)

plt.plot(x2[:6], x2[:6] ** 2, 'r', label = 'x^2')
plt.plot(x2[5:], x2[5:] ** 2, 'g--')

plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()

# %%
# Save graph

plt.figure(figsize=(5,3), dpi = 300)
plt.plot(x, y, 'b^--',label = '2x')
x2 = np.arange(0, 4, 0.5)

plt.plot(x2[:6], x2[:6] ** 2, 'r', label = 'x^2')
plt.plot(x2[5:], x2[5:] ** 2, 'g--')

plt.title('My First Graph', fontdict= {'fontname': 'Cosmic Sans Ms', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()
plt.savefig('my_graph.png', dpi = 300)

# %% [markdown]
# ## Bar Chart

# %%
lables = ['A','B','C']
values = [1,4,2]

plt.figure(figsize=(6,4))
bar = plt.bar(lables,values)
bar[0].set_hatch('/')
bar[1].set_hatch('*')
bar[2].set_hatch('.')
plt.show()

# %%
 lables = ['A','B','C']
values = [1,4,2]

plt.figure(figsize=(6,4))
bars = plt.bar(lables,values)

patterns = ['/','*','.']
for bar in bars:
    bar.set_hatch(patterns.pop())
plt.show()

# %% [markdown]
# ## Real World Examples

# %% [markdown]
# ### Line Graph

# %%
gas = pd.read_csv('gas_prices.csv')

plt.figure(figsize=(8,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(gas['Year'], gas['USA'], 'b.-', label='United States')
plt.plot(gas['Year'], gas['Canada'], 'r.-', label='Canada')
plt.plot(gas['Year'], gas['South Korea'], 'g.-', label='South Korea')
plt.plot(gas['Year'], gas['Australia'], 'y.-', label='Australia')

plt.xticks(gas['Year'][::3])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %% [markdown]
# ## Load Fifa Data

# %%
fifa = pd.read_csv('fifa_data.csv')

fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ## Histogram

# %%
bins = [40,50,60,70,80,90,100]

plt.figure(figsize=(8,5))

plt.hist(fifa['Overall'], bins=bins, color='green')

plt.xticks(bins)

plt.title('Distribution of Player Skills in FIFA 2018')
plt.xlabel('Skill Level')
plt.ylabel('Number of Players')

plt.savefig('histogram.png', dpi=300)

plt.show()

# %% [markdown]
# ## Pie Chart

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(8,5))

plt.title('Foot Preference of FIFA Players')
labels = ['Left', 'Right']
colors = ['red', 'blue']

# shows upto 2 decimal places
plt.pie([left, right], labels = labels, colors=colors, autopct='%.2f %%')

plt.show()

# %% [markdown]
# ## Exploring Pie chart

# %%
#gg plot
plt.figure(figsize=(8,5), dpi=100)

plt.style.use('ggplot')

# removing 'lbs' frim weight
fifa['Weight'] = [int(x.strip('lbs')) if type(x)==str else x for x in fifa['Weight']]

# ranging weights with respect to fifa['Weight']
light = fifa.loc[fifa['Weight'] < 125].count()[0]
light_medium = fifa[(fifa['Weight'] >= 125) & (fifa['Weight'] < 150)].count()[0]
medium = fifa[(fifa['Weight'] >= 150) & (fifa['Weight'] < 175)].count()[0]
medium_heavy = fifa[(fifa['Weight'] >= 175) & (fifa['Weight'] < 200)].count()[0]
heavy = fifa[fifa['Weight'] >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explode = (0.4,0.2,0,0,0.4)

plt.title('Weight of Professional Soccer Players (lbs)')

plt.pie(weights, labels=label, explode=explode, pctdistance=0.8,autopct='%.2f %%')
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(5,8), dpi=100)

plt.style.use('default')

barcelona = fifa.loc[fifa['Club'] == "FC Barcelona"]['Overall']
madrid = fifa.loc[fifa['Club'] == "Real Madrid"]['Overall']
revs = fifa.loc[fifa['Club'] == "New England Revolution"]['Overall']

plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

# set patch_artist = True to set box color, face color etc
bp = plt.boxplot([barcelona, madrid, revs], labels=['FC Barcelona','Real Madrid','NE Revolution'], patch_artist=True, medianprops={'linewidth': 2})

for box in bp['boxes']:
    # change outline color
    box.set(color='green', linewidth=2)
    # change fill color
    box.set(facecolor = 'grey' )
    # change hatch
    box.set(hatch = '/')
    
plt.show()
